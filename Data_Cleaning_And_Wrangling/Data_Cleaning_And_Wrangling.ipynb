# %%
import pandas as pd

# %%
q1 = pd.read_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/Origin_and_Destination_Survey_DB1BMarket_2021_1/Origin_and_Destination_Survey_DB1BMarket_2021_1.csv')
#print(q1.head())
print("Number of rows:", len(q1))
# Out:
# Number of rows: 3139631

# %%
print("Number of rows:", len(q1))
# Out:
# Number of rows: 3139631

# %%
q2 = pd.read_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/Origin_and_Destination_Survey_DB1BMarket_2021_2/Origin_and_Destination_Survey_DB1BMarket_2021_2.csv')
#print(q2.head())
print("Number of rows:", len(q2))
# Out:
# Number of rows: 5684862

# %%
q3 = pd.read_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/Origin_and_Destination_Survey_DB1BMarket_2021_3/Origin_and_Destination_Survey_DB1BMarket_2021_3.csv')
#print(q3.head())
print("Number of rows:", len(q3))
# Out:
# Number of rows: 6533649

# %%
q4 = pd.read_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/Origin_and_Destination_Survey_DB1BMarket_2021_4/Origin_and_Destination_Survey_DB1BMarket_2021_4.csv')
#print(q4.head())
print("Number of rows:", len(q4))
# Out:
# Number of rows: 6921910

# %%
concatenated_df = pd.concat([q1, q2, q3, q4], axis=0)
#print(concatenated_df.head())
print("Number of columns:", len(concatenated_df.columns))
print("Number of rows:", len(concatenated_df))
# Out:
# Number of columns: 42
# Number of rows: 22280052

# %%
unnecessary_columns = ['Year', 'OriginAirportID',
                       'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCountry',
                       'OriginStateFips', 'OriginState', 'OriginStateName',
                       'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 
                       'DestCountry', 'DestStateFips', 'DestState', 'DestStateName', 
                       'AirportGroup', 'WacGroup', 'TkCarrierGroup', 'OpCarrierGroup',
                       'MktDistanceGroup', 'ItinGeoType', 'Unnamed: 41']
correct_Data = concatenated_df.drop(unnecessary_columns, axis=1)

# %%
print("Number of columns:", len(correct_Data.columns))
print(correct_Data.columns)
print("Number of rows:", len(correct_Data))
# Out:
# Number of columns: 20
# Index(['ItinID', 'MktID', 'MktCoupons', 'Quarter', 'Origin', 'OriginWac',
#        'Dest', 'DestWac', 'TkCarrierChange', 'OpCarrierChange', 'RPCarrier',
#        'TkCarrier', 'OpCarrier', 'BulkFare', 'Passengers', 'MktFare',
#        'MktDistance', 'MktMilesFlown', 'NonStopMiles', 'MktGeoType'],
#       dtype='object')
# Number of rows: 22280052

# %%
correct_Data.to_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/new_flights_data.csv', index=False)

# %%
flights = pd.read_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/new_flights_data.csv')

# %%
print("Number of columns:", len(flights.columns))
print(flights.columns)
print("Number of rows:", len(flights))
print(flights.head())
# Out:
# Number of columns: 20
# Index(['ItinID', 'MktID', 'MktCoupons', 'Quarter', 'Origin', 'OriginWac',
#        'Dest', 'DestWac', 'TkCarrierChange', 'OpCarrierChange', 'RPCarrier',
#        'TkCarrier', 'OpCarrier', 'BulkFare', 'Passengers', 'MktFare',
#        'MktDistance', 'MktMilesFlown', 'NonStopMiles', 'MktGeoType'],
#       dtype='object')
# Number of rows: 22280052
#         ItinID          MktID  MktCoupons  Quarter Origin  OriginWac Dest  \
# 0  20211243122  2021124312202           1        1    PHL         23  LAX
# 1  20211243123  2021124312301           1        1    LAX         91  PHL
# 2  20211243123  2021124312302           1        1    PHL         23  LAX
# 3  20211243124  2021124312401           1        1    LAX         91  PHL
# 4  20211243124  2021124312402           1        1    PHL         23  LAX
#
#    DestWac  TkCarrierChange  OpCarrierChange RPCarrier TkCarrier OpCarrier  \
# 0       91              0.0              0.0        AA        AA        AA
# 1       23              0.0              0.0        AA        AA        AA
# 2       91              0.0              0.0        AA        AA        AA
# 3       23              0.0              0.0        AA        AA        AA
# 4       91              0.0              0.0        AA        AA        AA
#
#    BulkFare  Passengers  MktFare  MktDistance  MktMilesFlown  NonStopMiles  \
# 0       0.0         3.0     64.0       2402.0         2402.0        2402.0
# 1       0.0         2.0     68.5       2402.0         2402.0        2402.0
# 2       0.0         2.0     68.5       2402.0         2402.0        2402.0
# 3       0.0         3.0     70.5       2402.0         2402.0        2402.0
# 4       0.0         3.0     70.5       2402.0         2402.0        2402.0
#
#    MktGeoType
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2

# %%
flights = flights[flights['TkCarrierChange'] == 0]
flights = flights.drop(['TkCarrierChange'], axis=1)

# %%
flights = flights[flights['OpCarrierChange'] == 0]
flights = flights.drop(['OpCarrierChange'], axis=1)

# %%
flights = flights[(flights['RPCarrier'] == flights['TkCarrier']) & (flights['RPCarrier'] == flights['OpCarrier'])]
flights = flights.drop(['RPCarrier', 'OpCarrier'], axis=1)

# %%
flights = flights[flights['MktMilesFlown'] == flights['NonStopMiles']]
flights = flights.drop(['NonStopMiles'], axis=1)

# %%
flights = flights[(flights['MktDistance'] == flights['MktMilesFlown'])]
flights = flights.drop(['MktDistance'], axis=1)

# %%
flights = flights[(flights['MktFare'] >= 50) & (flights['MktFare'] <= 1000)]

# %%
flights = flights[(flights['TkCarrier'] != 'QX') & (flights['TkCarrier'] != 'OO') & (flights['TkCarrier'] != 'EV')]

# %%
flights = flights.drop(['BulkFare'], axis=1)

# %%
flights = flights[flights['Passengers'] <= 20]

# %%
flights
# Out:
#                 ItinID           MktID  MktCoupons  Quarter Origin  OriginWac  \
# 0          20211243122   2021124312202           1        1    PHL         23
# 1          20211243123   2021124312301           1        1    LAX         91
# 2          20211243123   2021124312302           1        1    PHL         23
# 3          20211243124   2021124312401           1        1    LAX         91
# 4          20211243124   2021124312402           1        1    PHL         23
# ...                ...             ...         ...      ...    ...        ...
# 22280025  202141242859  20214124285903           1        4    JFK         22
# 22280027  202141242860  20214124286003           1        4    JFK         22
# 22280029  202141242861  20214124286103           1        4    JFK         22
# 22280031  202141242862  20214124286203           1        4    JFK         22
# 22280033  202141242863  20214124286303           1        4    JFK         22
#
#          Dest  DestWac TkCarrier  Passengers  MktFare  MktMilesFlown  \
# 0         LAX       91        AA         3.0    64.00         2402.0
# 1         PHL       23        AA         2.0    68.50         2402.0
# 2         LAX       91        AA         2.0    68.50         2402.0
# 3         PHL       23        AA         3.0    70.50         2402.0
# 4         LAX       91        AA         3.0    70.50         2402.0
# ...       ...      ...       ...         ...      ...            ...
# 22280025  SFO       91        AS         1.0   119.59         2586.0
# 22280027  SFO       91        AS         1.0   120.50         2586.0
# 22280029  SFO       91        AS         1.0   133.69         2586.0
# 22280031  SFO       91        AS         1.0   196.89         2586.0
# 22280033  SFO       91        AS         1.0   654.80         2586.0
#
#           MktGeoType
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# ...              ...
# 22280025           2
# 22280027           2
# 22280029           2
# 22280031           2
# 22280033           2
#
# [7613643 rows x 13 columns]

# %%
flights['Miles'] = flights['MktMilesFlown']
flights = flights.drop(['MktMilesFlown'], axis=1)

# %%
flights['ContiguousUSA'] = flights['MktGeoType']
flights = flights.drop(['MktGeoType'], axis=1)

# %%
flights['NumTicketsOrdered'] = flights['Passengers']
flights = flights.drop(['Passengers'], axis=1)

# %%
flights['AirlineCompany'] = flights['TkCarrier']
flights = flights.drop(['TkCarrier'], axis=1)

# %%
flights['PricePerTicket'] = flights['MktFare']
flights = flights.drop(['MktFare'], axis=1)

# %%
flights
# Out:
#                 ItinID           MktID  MktCoupons  Quarter Origin  OriginWac  \
# 0          20211243122   2021124312202           1        1    PHL         23
# 1          20211243123   2021124312301           1        1    LAX         91
# 2          20211243123   2021124312302           1        1    PHL         23
# 3          20211243124   2021124312401           1        1    LAX         91
# 4          20211243124   2021124312402           1        1    PHL         23
# ...                ...             ...         ...      ...    ...        ...
# 22280025  202141242859  20214124285903           1        4    JFK         22
# 22280027  202141242860  20214124286003           1        4    JFK         22
# 22280029  202141242861  20214124286103           1        4    JFK         22
# 22280031  202141242862  20214124286203           1        4    JFK         22
# 22280033  202141242863  20214124286303           1        4    JFK         22
#
#          Dest  DestWac   Miles  ContiguousUSA  NumTicketsOrdered  \
# 0         LAX       91  2402.0              2                3.0
# 1         PHL       23  2402.0              2                2.0
# 2         LAX       91  2402.0              2                2.0
# 3         PHL       23  2402.0              2                3.0
# 4         LAX       91  2402.0              2                3.0
# ...       ...      ...     ...            ...                ...
# 22280025  SFO       91  2586.0              2                1.0
# 22280027  SFO       91  2586.0              2                1.0
# 22280029  SFO       91  2586.0              2                1.0
# 22280031  SFO       91  2586.0              2                1.0
# 22280033  SFO       91  2586.0              2                1.0
#
#          AirlineCompany  PricePerTicket
# 0                    AA           64.00
# 1                    AA           68.50
# 2                    AA           68.50
# 3                    AA           70.50
# 4                    AA           70.50
# ...                 ...             ...
# 22280025             AS          119.59
# 22280027             AS          120.50
# 22280029             AS          133.69
# 22280031             AS          196.89
# 22280033             AS          654.80
#
# [7613643 rows x 13 columns]

# %%
flights = flights.reset_index(drop=True)
flights
# Out:
#                ItinID           MktID  MktCoupons  Quarter Origin  OriginWac  \
# 0         20211243122   2021124312202           1        1    PHL         23
# 1         20211243123   2021124312301           1        1    LAX         91
# 2         20211243123   2021124312302           1        1    PHL         23
# 3         20211243124   2021124312401           1        1    LAX         91
# 4         20211243124   2021124312402           1        1    PHL         23
# ...               ...             ...         ...      ...    ...        ...
# 7613638  202141242859  20214124285903           1        4    JFK         22
# 7613639  202141242860  20214124286003           1        4    JFK         22
# 7613640  202141242861  20214124286103           1        4    JFK         22
# 7613641  202141242862  20214124286203           1        4    JFK         22
# 7613642  202141242863  20214124286303           1        4    JFK         22
#
#         Dest  DestWac   Miles  ContiguousUSA  NumTicketsOrdered  \
# 0        LAX       91  2402.0              2                3.0
# 1        PHL       23  2402.0              2                2.0
# 2        LAX       91  2402.0              2                2.0
# 3        PHL       23  2402.0              2                3.0
# 4        LAX       91  2402.0              2                3.0
# ...      ...      ...     ...            ...                ...
# 7613638  SFO       91  2586.0              2                1.0
# 7613639  SFO       91  2586.0              2                1.0
# 7613640  SFO       91  2586.0              2                1.0
# 7613641  SFO       91  2586.0              2                1.0
# 7613642  SFO       91  2586.0              2                1.0
#
#         AirlineCompany  PricePerTicket
# 0                   AA           64.00
# 1                   AA           68.50
# 2                   AA           68.50
# 3                   AA           70.50
# 4                   AA           70.50
# ...                ...             ...
# 7613638             AS          119.59
# 7613639             AS          120.50
# 7613640             AS          133.69
# 7613641             AS          196.89
# 7613642             AS          654.80
#
# [7613643 rows x 13 columns]

# %%
flights.to_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/flights_data.csv', index=False)

# %%
flights_data = pd.read_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/flights_data.csv')

# %%
print("Number of columns:", len(flights_data.columns))
print(flights_data.columns)
print("Number of rows:", len(flights_data))
print(flights_data.head())
# Out:
# Number of columns: 13
# Index(['ItinID', 'MktID', 'MktCoupons', 'Quarter', 'Origin', 'OriginWac',
#        'Dest', 'DestWac', 'Miles', 'ContiguousUSA', 'NumTicketsOrdered',
#        'AirlineCompany', 'PricePerTicket'],
#       dtype='object')
# Number of rows: 7613643
#         ItinID          MktID  MktCoupons  Quarter Origin  OriginWac Dest  \
# 0  20211243122  2021124312202           1        1    PHL         23  LAX
# 1  20211243123  2021124312301           1        1    LAX         91  PHL
# 2  20211243123  2021124312302           1        1    PHL         23  LAX
# 3  20211243124  2021124312401           1        1    LAX         91  PHL
# 4  20211243124  2021124312402           1        1    PHL         23  LAX
#
#    DestWac   Miles  ContiguousUSA  NumTicketsOrdered AirlineCompany  \
# 0       91  2402.0              2                3.0             AA
# 1       23  2402.0              2                2.0             AA
# 2       91  2402.0              2                2.0             AA
# 3       23  2402.0              2                3.0             AA
# 4       91  2402.0              2                3.0             AA
#
#    PricePerTicket
# 0            64.0
# 1            68.5
# 2            68.5
# 3            70.5
# 4            70.5

# %%
flights_data
# Out:
#                ItinID           MktID  MktCoupons  Quarter Origin  OriginWac  \
# 0         20211243122   2021124312202           1        1    PHL         23
# 1         20211243123   2021124312301           1        1    LAX         91
# 2         20211243123   2021124312302           1        1    PHL         23
# 3         20211243124   2021124312401           1        1    LAX         91
# 4         20211243124   2021124312402           1        1    PHL         23
# ...               ...             ...         ...      ...    ...        ...
# 7613638  202141242859  20214124285903           1        4    JFK         22
# 7613639  202141242860  20214124286003           1        4    JFK         22
# 7613640  202141242861  20214124286103           1        4    JFK         22
# 7613641  202141242862  20214124286203           1        4    JFK         22
# 7613642  202141242863  20214124286303           1        4    JFK         22
#
#         Dest  DestWac   Miles  ContiguousUSA  NumTicketsOrdered  \
# 0        LAX       91  2402.0              2                3.0
# 1        PHL       23  2402.0              2                2.0
# 2        LAX       91  2402.0              2                2.0
# 3        PHL       23  2402.0              2                3.0
# 4        LAX       91  2402.0              2                3.0
# ...      ...      ...     ...            ...                ...
# 7613638  SFO       91  2586.0              2                1.0
# 7613639  SFO       91  2586.0              2                1.0
# 7613640  SFO       91  2586.0              2                1.0
# 7613641  SFO       91  2586.0              2                1.0
# 7613642  SFO       91  2586.0              2                1.0
#
#         AirlineCompany  PricePerTicket
# 0                   AA           64.00
# 1                   AA           68.50
# 2                   AA           68.50
# 3                   AA           70.50
# 4                   AA           70.50
# ...                ...             ...
# 7613638             AS          119.59
# 7613639             AS          120.50
# 7613640             AS          133.69
# 7613641             AS          196.89
# 7613642             AS          654.80
#
# [7613643 rows x 13 columns]

# %%
flights_data.to_csv('/Users/himanshutalele/Desktop/DS/Project/RAW_DATA/Cleaned_data.csv', index=False)

# %%
Cleaned_data = pd.read_csv('/Users/himanshutalele/Desktop/DS/Project/Data_Cleaning_And_Wrangling/Cleaned_data.csv')

# %%
Cleaned_data
# Out:
#                ItinID           MktID  MktCoupons  Quarter Origin  OriginWac  \
# 0         20211243122   2021124312202           1        1    PHL         23
# 1         20211243123   2021124312301           1        1    LAX         91
# 2         20211243123   2021124312302           1        1    PHL         23
# 3         20211243124   2021124312401           1        1    LAX         91
# 4         20211243124   2021124312402           1        1    PHL         23
# ...               ...             ...         ...      ...    ...        ...
# 7613638  202141242859  20214124285903           1        4    JFK         22
# 7613639  202141242860  20214124286003           1        4    JFK         22
# 7613640  202141242861  20214124286103           1        4    JFK         22
# 7613641  202141242862  20214124286203           1        4    JFK         22
# 7613642  202141242863  20214124286303           1        4    JFK         22
#
#         Dest  DestWac   Miles  ContiguousUSA  NumTicketsOrdered  \
# 0        LAX       91  2402.0              2                3.0
# 1        PHL       23  2402.0              2                2.0
# 2        LAX       91  2402.0              2                2.0
# 3        PHL       23  2402.0              2                3.0
# 4        LAX       91  2402.0              2                3.0
# ...      ...      ...     ...            ...                ...
# 7613638  SFO       91  2586.0              2                1.0
# 7613639  SFO       91  2586.0              2                1.0
# 7613640  SFO       91  2586.0              2                1.0
# 7613641  SFO       91  2586.0              2                1.0
# 7613642  SFO       91  2586.0              2                1.0
#
#         AirlineCompany  PricePerTicket
# 0                   AA           64.00
# 1                   AA           68.50
# 2                   AA           68.50
# 3                   AA           70.50
# 4                   AA           70.50
# ...                ...             ...
# 7613638             AS          119.59
# 7613639             AS          120.50
# 7613640             AS          133.69
# 7613641             AS          196.89
# 7613642             AS          654.80
#
# [7613643 rows x 13 columns]
